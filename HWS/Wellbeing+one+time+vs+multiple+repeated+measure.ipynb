# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df=pd.read_csv('H:\XIAOXI_JNJ\Wellbeing DTC\Final Dataset_New&Old\One Time vs Multiple\Merged_Final data_NoMissing_Repeated Measure.csv',na_values=999)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 23 columns):
# WWID             85 non-null object
# Date             85 non-null object
# Pre_Q25          84 non-null float64
# Pre_Q26          84 non-null float64
# Pre_Q27          84 non-null float64
# Pre_Q28          84 non-null float64
# Pre_Q29          85 non-null int64
# Pre_Q30          83 non-null float64
# Pre_Q11          84 non-null float64
# Pre_Q12          84 non-null float64
# Pre_Q13          83 non-null float64
# Pre_Q14          83 non-null float64
# Pre_Q15          80 non-null float64
# Post_Q25         85 non-null int64
# Post_Q26         85 non-null int64
# Post_Q27         84 non-null float64
# Post_Q28         84 non-null float64
# Post_Q29         85 non-null int64
# Post_Q30         83 non-null float64
# Post_Q8          84 non-null float64
# Post_Q9          85 non-null int64
# Post_Q14         83 non-null float64
# MatchSequence    85 non-null int64
# ...

# %%
df.head()
# Out:
#       WWID       Date  Pre_Q25  Pre_Q26  Pre_Q27  Pre_Q28  Pre_Q29  Pre_Q30  \
# 0  1040543  3/12/2018      7.0      NaN      7.0      NaN        8      5.0
# 1  1040543  4/18/2018      NaN      6.0      7.0      6.0        6      5.0
# 2  1046682  3/16/2018     10.0     10.0      9.0      7.0        8      8.0
# 3  1046682  3/19/2018      7.0      8.0      7.0      7.0        8      8.0
# 4  1051889  2/26/2018      5.0      8.0      8.0      6.0        4      8.0
#
#    Pre_Q11  Pre_Q12      ...        Post_Q25  Post_Q26  Post_Q27  Post_Q28  \
# 0      4.0      3.0      ...               9         9       8.0       9.0
# 1      4.0      4.0      ...              10         8       7.0       8.0
# 2      5.0      5.0      ...              10        10       9.0       8.0
# 3      5.0      5.0      ...               8         8       8.0       7.0
# 4      4.0      4.0      ...               8         9       9.0       8.0
#
# ...

# %%
df['WWID']=df['WWID'].astype(str)

# %%
sns.set(rc={'figure.figsize':(21,7)})

# %% [markdown]
# ## Energized Pre and Post

# %%
ax = sns.barplot(x="WWID", y="Pre_Q25", hue="MatchSequence",data=df,palette="husl")
sns.plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %%
ax = sns.barplot(x="WWID", y="Post_Q25", hue="MatchSequence", data=df)
sns.plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %% [markdown]
# ## Hopeful Pre and Post

# %%
ax = sns.barplot(x="WWID", y="Pre_Q26", hue="MatchSequence",data=df,palette="husl")
sns.plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %%
ax = sns.barplot(x="WWID", y="Post_Q26", hue="MatchSequence", data=df)
sns.plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %% [markdown]
# ## Joyful Pre and Post

# %%
ax = sns.barplot(x="WWID", y="Pre_Q27", hue="MatchSequence",data=df,palette="husl")
sns.plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %%
ax = sns.barplot(x="WWID", y="Post_Q27", hue="MatchSequence", data=df)
sns.plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %% [markdown]
# ## Relax Pre and Post

# %%
ax = sns.barplot(x="WWID", y="Pre_Q28", hue="MatchSequence",data=df,palette="husl")
sns.plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %%
ax = sns.barplot(x="WWID", y="Post_Q28", hue="MatchSequence", data=df)
sns.plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %% [markdown]
# ## Stressed Pre and Post

# %%
ax = sns.barplot(x="WWID", y="Pre_Q29", hue="MatchSequence",data=df,palette="husl")
sns.plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %%
ax = sns.barplot(x="WWID", y="Post_Q29", hue="MatchSequence", data=df)
sns.plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %% [markdown]
# ## Purpose in Life Pre and Post

# %%
ax = sns.barplot(x="WWID", y="Pre_Q30", hue="MatchSequence",data=df,palette="husl")
sns.plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %%
ax = sns.barplot(x="WWID", y="Post_Q30", hue="MatchSequence", data=df)
sns.plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %% [markdown]
# ## Likelihood Recommend to others

# %%
ax = sns.barplot(x="WWID", y="Post_Q9", hue="MatchSequence", data=df)
sns.plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %% [markdown]
# ## Overall Enjoyment

# %%
ax = sns.barplot(x="WWID", y="Post_Q14", hue="MatchSequence", data=df)
sns.plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %% [markdown]
# ## In General My health is

# %%
ax = sns.barplot(x="WWID", y="Pre_Q11", hue="MatchSequence", data=df)
sns.plt.ylim(0, 5)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %% [markdown]
# ## In General My Wellbeing is

# %%
ax = sns.barplot(x="WWID", y="Pre_Q12", hue="MatchSequence", data=df)
sns.plt.ylim(0, 5)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %% [markdown]
# ## Frequency of using fitness facility

# %%
ax = sns.barplot(x="WWID", y="Pre_Q13", hue="MatchSequence", data=df)
sns.plt.ylim(0, 5)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %% [markdown]
# ## Motivated to improve wellbeing

# %%
ax = sns.barplot(x="WWID", y="Pre_Q14", hue="MatchSequence", data=df)
sns.plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)

# %% [markdown]
# ## Confident to inprove wellbeing

# %%
ax = sns.barplot(x="WWID", y="Pre_Q15", hue="MatchSequence", data=df)
sns.plt.ylim(0, 10)
plt.legend(bbox_to_anchor=(1.04, 1),loc=1, borderaxespad=0.)
